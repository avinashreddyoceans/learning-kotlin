# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashreddyoceans/learning-kotlin/blob/main/DA/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
a = 87968689
b = 899327097
print("sum of numbers :", a + b)
# Out:
# sum of numbers : 987295786
